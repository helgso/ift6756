# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 14}

matplotlib.rc('font', **font)

# %% [markdown]
# ## Experiment 1

# %%
x1 = np.arange(12)
y1 = [0.9498, 1.6019, 1.2752, 1.3736, 1.2360, 1.2598, 1.7875, 1.0410, 1.6476, 1.2170, 0.9085, 1.3990]
plt.plot(x1, y1, label = "Z target")

x2 = np.arange(12)
y2 = [0.6348, 0.4769, 0.8727, 1.1156, 0.6124, 0.9121, 0.3868, 0.3507, 0.3467, 0.2928, 0.2082, 0.2612]
plt.plot(x2, y2, label = "Q target")

plt.xlabel('Epoch')
plt.ylabel('Value head MSE')
plt.xticks(np.arange(0, 12, 1))

plt.legend(loc="upper right")
plt.show()

# %%
x1 = np.arange(12)
y1 = [4.8548, 5.0332, 5.0093, 4.8998, 4.7948, 4.8653, 4.7103, 4.9576, 4.6935, 4.7206, 4.8126, 4.8997]
plt.plot(x1, y1, label = "Z target")

x2 = np.arange(12)
y2 = [4.8542, 4.7950, 4.7777, 4.8447, 4.8461, 4.8097, 4.8085, 4.7252, 4.7455, 4.7375, 4.7472, 4.6638]
plt.plot(x2, y2, label = "Q target")

plt.xlabel('Epoch')
plt.ylabel('Policy head CCE')
plt.xticks(np.arange(0, 12, 1))

plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# ## Experiment 2

# %%
x1 = np.arange(12)
y1 = [0.1415, 0.5988, 1.7770, 0.1203, 0.0554, 0.0257, 1.8310, 1.9206, 1.9562, 0.8779, 0.0986, 1.9521]
plt.plot(x1, y1, label = "Z target")

x2 = np.arange(12)
y2 = [0.0359, 0.0274, 0.0216, 0.0196, 0.0086, 0.0081, 0.0078, 0.0073, 0.0054, 0.0075, 0.0047, 0.0065]
plt.plot(x2, y2, label = "Q target")

plt.xlabel('Epoch')
plt.ylabel('Value head MSE')
plt.xticks(np.arange(0, 12, 1))

plt.legend(loc="upper right")
plt.show()

# %%
x1 = np.arange(12)
y1 = [7.4845, 5.0670, 4.7528, 4.8882, 4.4395, 4.2995, 4.5276, 4.5595, 4.4382, 4.4170, 4.2422, 4.3340]
plt.plot(x1, y1, label = "Z target")

x2 = np.arange(12)
y2 = [6.3556, 4.8353, 4.3979, 4.3810, 4.3193, 4.2784, 4.2569, 4.2772, 4.2186, 4.2402, 4.3751, 4.3420]
plt.plot(x2, y2, label = "Q target")

plt.xlabel('Epoch')
plt.ylabel('Policy head CCE')
plt.xticks(np.arange(0, 12, 1))

plt.legend(loc="upper right")
plt.show()
